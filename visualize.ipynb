# %%
import numpy as np

# 假设你的深度图文件名为 depth.npy
depth = np.load('/home/liuwei/mnt/instant_vggt_dataset/TartanAir_unpacked/abandonedfactory/abandonedfactory/Hard/P000/000083_depth.npy')
import matplotlib.pyplot as plt

plt.imshow(depth, cmap='plasma')  # 'plasma' 或 'viridis' 更容易看深度
plt.colorbar(label='Depth (m)')
plt.show()
